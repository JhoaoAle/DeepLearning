# %%
import torch
from torchvision import transforms
from PIL import Image
import sys
import os
import matplotlib.pyplot as plt

PROJECT_ROOT = os.path.abspath("...")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.lsc_classifier.classification.model import LSCClassifier
from src.lsc_classifier.visualization.viz_utils import visualize_activations

# %%
num_classes = 21
model = LSCClassifier(num_classes=num_classes)

# Uncomment if you have a trained model
# model.load_state_dict(torch.load("data/models/lsc_model.pth"))

# %%
sample_img_path = os.path.join(
    "..", "data", "processed", "train", "a", "a_001.jpg"
)

img = Image.open(sample_img_path).convert("RGB")

transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
])

img_tensor = transform(img).unsqueeze(0)

# %%
plt.imshow(img)
plt.axis("off")
plt.title("Original Image")
plt.show()

# %%
visualize_activations(model, img_tensor)
